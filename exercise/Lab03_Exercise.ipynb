# %% [markdown]
# # Lab 03: Text Chunking - Exercise
#
# **Total Points:** 100 (25 each) | **Time:** ~45 minutes
#
# ---

# %% [markdown]
# ## Exercise 1: Split Text by Characters (25 pts)
#
# Split the text below into chunks of **10 characters** each.
# Store the result in a list called `chunks`.

# %%
text = "Rubella causes fever and rash in patients"
chunk_size = 10

# YOUR CODE HERE
chunks = []


# Check your answer
print(f"Number of chunks: {len(chunks)}")
for i, c in enumerate(chunks):
    print(f"  Chunk {i+1}: '{c}'")

# %%
# Quick check (structure only)
if isinstance(chunks, list):
    print(f"✅ chunks is a list")
    print(f"   Number of chunks: {len(chunks)}")
    if len(chunks) > 0:
        print(f"   First chunk length: {len(chunks[0])} characters")
    else:
        print(f"❌ chunks list is empty")
else:
    print(f"❌ chunks should be a list")

# %% [markdown]
# ---
#
# ## Exercise 2: Create Chunk Function (25 pts)
#
# Create a function `create_chunks(text, size)` that:
# - Takes text and chunk size as parameters
# - Returns a list of chunks

# %%
# YOUR CODE HERE
def create_chunks(text, size):
    """Split text into chunks of given size."""
    pass  # Replace with your code


# Check your answer
result = create_chunks("ABCDEFGHIJ", 3)
print(f"Result: {result}")

# %%
# Quick check (structure only)
result = create_chunks("ABCDEFGHIJ", 3)
if result is not None:
    print(f"✅ Function returns a value")
    if isinstance(result, list):
        print(f"✅ Function returns a list")
        print(f"   Number of items: {len(result)}")
    else:
        print(f"❌ Function should return a list")
else:
    print(f"❌ Function returns None")

# %% [markdown]
# ---
#
# ## Exercise 3: Chunk with Overlap (25 pts)
#
# Create a function `chunk_overlap(text, size, overlap)` that:
# - Splits text with overlapping characters
# - Returns list of overlapping chunks

# %%
# YOUR CODE HERE
def chunk_overlap(text, size, overlap):
    """Split text into chunks with overlap."""
    pass  # Replace with your code


# Check your answer
result = chunk_overlap("ABCDEFGHIJKLMNO", 6, 2)
print(f"Result: {result}")

# %%
# Quick check (structure only)
result = chunk_overlap("ABCDEFGHIJKLMNO", 6, 2)
if result is not None:
    print(f"✅ Function returns a value")
    if isinstance(result, list):
        print(f"✅ Function returns a list")
        print(f"   Number of chunks: {len(result)}")
        if len(result) >= 2:
            # Check if overlap exists (without revealing exact values)
            if result[0][-2:] == result[1][:2]:
                print(f"✅ Overlap detected between chunks")
            else:
                print(f"❌ Overlap not working correctly")
    else:
        print(f"❌ Function should return a list")
else:
    print(f"❌ Function returns None")

# %% [markdown]
# ---
#
# ## Exercise 4: Chunk a Document (25 pts)
#
# Using your `create_chunks` function:
# 1. Chunk the document below with size 50
# 2. Store the number of chunks in `num_chunks`
# 3. Store the first chunk text in `first_chunk`

# %%
document = """Cholera is an acute diarrheal infection caused by ingestion of contaminated water. 
Symptoms include severe watery diarrhea and vomiting. Treatment focuses on rehydration therapy."""

# YOUR CODE HERE
num_chunks = None
first_chunk = None


# Check your answer
print(f"Number of chunks: {num_chunks}")
print(f"First chunk: '{first_chunk}'")

# %%
# Quick check (structure only)
if num_chunks is not None:
    print(f"✅ num_chunks has a value: {num_chunks}")
    if isinstance(num_chunks, int):
        print(f"✅ num_chunks is an integer")
    else:
        print(f"❌ num_chunks should be an integer")
else:
    print(f"❌ num_chunks is still None")

if first_chunk is not None:
    print(f"✅ first_chunk has a value")
    print(f"   Length: {len(first_chunk)} characters")
else:
    print(f"❌ first_chunk is still None")

# %% [markdown]
# ---
#
# ## 🎉 Finished!
#
# ### Summary:
# | Exercise | Skill |
# |----------|-------|
# | 1 | Manual chunking with loop |
# | 2 | Create reusable function |
# | 3 | Add overlap for context |
# | 4 | Apply to real documents |
#
# ### Submit:
# ```bash
# git add . && git commit -m "Complete Lab 03" && git push
# ```
#
# Check your score in GitHub Actions tab!
